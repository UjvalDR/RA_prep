# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas-K-S/Detection-of-RA-Using-CNN/blob/main/TrainingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unrar
#!unrar x "/content/Source images.rar" #//unrar images folder

# %%
# import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# accessing image folder for training and testing
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Source images",
    shuffle = True, 
    image_size = (256, 256), 
    batch_size = 8
)
# Out:
# Found 87 files belonging to 2 classes.

# %%
class_names = dataset.class_names

# %%
class_names
# Out:
# ['negative', 'positive']

# %%
# vizualizing the random images
plt.figure(figsize=(20,10))
for image_batch, lable_batch in dataset.take(1):
    for i in range(8):
        ax = plt.subplot(2,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[lable_batch[i]])
        plt.axis("off")

# %%
# function to split dataset into training set, testing set and validation set
def split_dataset(ds, train_split = 0.8, test_split = 0.1, val_split = 0.1, Shuffle = True, shuffle_size = 1000):
    ds_len = len(ds)
    if Shuffle:
        ds = ds.shuffle(shuffle_size, seed = 10)
    
    train_size = int(ds_len*train_split)
    val_size = int(ds_len*val_split)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, test_ds, val_ds

# %%
# calling the split_dataset function to split the dataset
train_ds, test_ds, val_ds = split_dataset(dataset)

# %%
#creating resizeing and rescaleing layer
resize_rescale = tf.keras.Sequential([
                                      layers.Resizing(256, 256),
                                      layers.Rescaling(1.0/255)

])

# %%
# creating data augmentation layer
data_augmentation = tf.keras.Sequential([
                                         layers.RandomFlip("horizontal_and_vertical"),
                                         layers.RandomRotation(0.2)
])

# %%
# creating the CNN model
input_shape = (8, 256,256, 3)

model = models.Sequential([
                           resize_rescale,
                           data_augmentation,
                           layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(32, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Flatten(),
                           layers.Dense(32, activation='relu'),
                           layers.Dense(2, activation='softmax'),
])
model.build(input_shape=input_shape)

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 256, 256, 3)       0
#
#  sequential_4 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_10 (Conv2D)          (8, 254, 254, 32)         896
#
#  max_pooling2d_10 (MaxPoolin  (8, 127, 127, 32)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (8, 125, 125, 64)         18496
#
#  max_pooling2d_11 (MaxPoolin  (8, 62, 62, 64)          0
#  g2D)
#
#  conv2d_12 (Conv2D)          (8, 60, 60, 64)           36928
#
#  max_pooling2d_12 (MaxPoolin  (8, 30, 30, 64)          0
#  g2D)
#
#  conv2d_13 (Conv2D)          (8, 28, 28, 64)           36928
#
#  max_pooling2d_13 (MaxPoolin  (8, 14, 14, 64)          0
#  g2D)
#
#  conv2d_14 (Conv2D)          (8, 12, 12, 32)           18464
#
#  max_pooling2d_14 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  flatten_3 (Flatten)         (8, 1152)                 0
#
#  dense_6 (Dense)             (8, 32)                   36896
#
#  dense_7 (Dense)             (8, 2)                    66
#
# =================================================================
# Total params: 148,674
# Trainable params: 148,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling model
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %%
# fitting the model
history = model.fit(
    train_ds,
    epochs=25,
    batch_size = 8,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 5s 202ms/step - loss: 0.6857 - accuracy: 0.5079 - val_loss: 0.5926 - val_accuracy: 0.7143
# Epoch 2/25
# 8/8 [==============================] - 2s 154ms/step - loss: 0.6535 - accuracy: 0.5156 - val_loss: 0.5889 - val_accuracy: 0.7143
# Epoch 3/25
# 8/8 [==============================] - 2s 147ms/step - loss: 0.6583 - accuracy: 0.4921 - val_loss: 0.7984 - val_accuracy: 0.2500
# Epoch 4/25
# 8/8 [==============================] - 2s 141ms/step - loss: 0.6653 - accuracy: 0.6825 - val_loss: 0.6280 - val_accuracy: 1.0000
# Epoch 5/25
# 8/8 [==============================] - 2s 156ms/step - loss: 0.6393 - accuracy: 0.7460 - val_loss: 0.4425 - val_accuracy: 0.8750
# Epoch 6/25
# 8/8 [==============================] - 2s 162ms/step - loss: 0.5051 - accuracy: 0.7969 - val_loss: 0.4143 - val_accuracy: 0.7500
# Epoch 7/25
# 8/8 [==============================] - 1s 157ms/step - loss: 0.5515 - accuracy: 0.7778 - val_loss: 0.2489 - val_accuracy: 1.0000
# Epoch 8/25
# 8/8 [==============================] - 2s 157ms/step - loss: 0.4052 - accuracy: 0.8438 - val_loss: 0.1877 - val_accuracy: 0.8750
# Epoch 9/25
# 8/8 [==============================] - 2s 181ms/step - loss: 0.4103 - accuracy: 0.8095 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 10/25
# 8/8 [==============================] - 2s 174ms/step - loss: 0.3308 - accuracy: 0.8889 - val_loss: 0.6293 - val_accuracy: 0.8750
# Epoch 11/25
# 8/8 [==============================] - 2s 170ms/step - loss: 0.3362 - accuracy: 0.8254 - val_loss: 0.1357 - val_accuracy: 1.0000
# Epoch 12/25
# 8/8 [==============================] - 2s 179ms/step - loss: 0.4230 - accuracy: 0.8281 - val_loss: 0.2629 - val_accuracy: 0.8750
# Epoch 13/25
# 8/8 [==============================] - 2s 178ms/step - loss: 0.3801 - accuracy: 0.7812 - val_loss: 0.6212 - val_accuracy: 0.7500
# Epoch 14/25
# 8/8 [==============================] - 2s 179ms/step - loss: 0.2920 - accuracy: 0.8750 - val_loss: 0.3044 - val_accuracy: 0.8750
# Epoch 15/25
# 8/8 [==============================] - 2s 190ms/step - loss: 0.4333 - accuracy: 0.8095 - val_loss: 0.0902 - val_accuracy: 1.0000
# Epoch 16/25
# 8/8 [==============================] - 2s 178ms/step - loss: 0.4385 - accuracy: 0.8571 - val_loss: 0.5079 - val_accuracy: 0.7500
# Epoch 17/25
# 8/8 [==============================] - 2s 176ms/step - loss: 0.4147 - accuracy: 0.7937 - val_loss: 0.3171 - val_accuracy: 0.8750
# Epoch 18/25
# 8/8 [==============================] - 2s 174ms/step - loss: 0.3054 - accuracy: 0.8571 - val_loss: 0.7243 - val_accuracy: 0.7500
# Epoch 19/25
# 8/8 [==============================] - 2s 136ms/step - loss: 0.2672 - accuracy: 0.8730 - val_loss: 0.2470 - val_accuracy: 0.8750
# Epoch 20/25
# 8/8 [==============================] - 2s 182ms/step - loss: 0.4968 - accuracy: 0.8438 - val_loss: 0.9234 - val_accuracy: 0.6250
# Epoch 21/25
# 8/8 [==============================] - 2s 190ms/step - loss: 0.4194 - accuracy: 0.8254 - val_loss: 0.2594 - val_accuracy: 0.8750
# Epoch 22/25
# 8/8 [==============================] - 2s 167ms/step - loss: 0.3160 - accuracy: 0.8730 - val_loss: 0.2273 - val_accuracy: 0.8750
# Epoch 23/25
# 8/8 [==============================] - 2s 164ms/step - loss: 0.3210 - accuracy: 0.8889 - val_loss: 0.7095 - val_accuracy: 0.7500
# Epoch 24/25
# 8/8 [==============================] - 2s 181ms/step - loss: 0.2681 - accuracy: 0.8889 - val_loss: 0.3858 - val_accuracy: 0.7500
# Epoch 25/25
# 8/8 [==============================] - 2s 162ms/step - loss: 0.2945 - accuracy: 0.8254 - val_loss: 0.3587 - val_accuracy: 0.8750

# %%
# Testing the created model aganist the test dataset
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 40ms/step - loss: 0.2204 - accuracy: 0.9375
# [0.22044633328914642, 0.9375]

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# plotting the training accuracy and validation accuracy
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(range(25), accuracy, label='Training Accuracy')
plt.plot(range(25), val_accuracy, label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
# model.save("Saved_model_v2.h5")

# %%
plt.figure(figsize=(20,10))
for image_batch, lable_batch in test_ds.take(1):
    for i in range(8):
        ax = plt.subplot(2,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[lable_batch[i]])
        plt.axis("off")

# %%
img = resize_rescale(image_batch[0])
# img = data_augmentation(img)
plt.imshow(img)

# %%
from PIL import Image
import numpy as np  
import matplotlib.image as mpimg
from io import BytesIO

# %%
img = Image.open(r"Source images\positive\pos 35.jpg")
img = img.resize((256,256))
img = np.array(img)
img = np.expand_dims(img, axis=0)
prediction = class_names [np.argmax(model.predict(img))]
print(prediction)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# positive
