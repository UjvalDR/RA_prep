# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas-K-S/Detection-of-RA-Using-CNN/blob/main/TrainingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unrar
#!unrar x "/content/Source images.rar" #//unrar images folder

# %%
# import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# accessing image folder for training and testing
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/Source images",
    shuffle = True, 
    image_size = (256, 256), 
    batch_size = 8
)
# Out:
# Found 87 files belonging to 2 classes.

# %%
class_names = dataset.class_names

# %%
class_names
# Out:
# ['negative', 'positive']

# %%
# vizualizing the random images
plt.figure(figsize=(20,10))
for image_batch, lable_batch in dataset.take(1):
    for i in range(8):
        ax = plt.subplot(2,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[lable_batch[i]])
        plt.axis("off")

# %%
# function to split dataset into training set, testing set and validation set
def split_dataset(ds, train_split = 0.8, test_split = 0.1, val_split = 0.1, Shuffle = True, shuffle_size = 1000):
    ds_len = len(ds)
    if Shuffle:
        ds = ds.shuffle(shuffle_size, seed = 10)
    
    train_size = int(ds_len*train_split)
    val_size = int(ds_len*val_split)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, test_ds, val_ds

# %%
# calling the split_dataset function to split the dataset
train_ds, test_ds, val_ds = split_dataset(dataset)

# %%
#creating resizeing and rescaleing layer
resize_rescale = tf.keras.Sequential([
                                      layers.Resizing(256, 256),
                                      layers.Rescaling(1.0/255)

])

# %%
# creating data augmentation layer
data_augmentation = tf.keras.Sequential([
                                         layers.RandomFlip("horizontal_and_vertical"),
                                         layers.RandomRotation(0.2)
])

# %%
# creating the CNN model
input_shape = (8, 256,256, 3)

model = models.Sequential([
                           resize_rescale,
                           data_augmentation,
                           layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                        #    layers.Conv2D(64, (3,3), activation='relu'),
                        #    layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Conv2D(64, (3,3), activation='relu'),
                           layers.MaxPool2D(),
                           layers.Flatten(),
                           layers.Dense(64, activation='relu'),
                           layers.Dense(2, activation='softmax'),
])
model.build(input_shape=input_shape)

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 256, 256, 3)       0
#
#  sequential_4 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_10 (Conv2D)          (8, 254, 254, 32)         896
#
#  max_pooling2d_10 (MaxPoolin  (8, 127, 127, 32)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (8, 125, 125, 64)         18496
#
#  max_pooling2d_11 (MaxPoolin  (8, 62, 62, 64)          0
#  g2D)
#
#  conv2d_12 (Conv2D)          (8, 60, 60, 64)           36928
#
#  max_pooling2d_12 (MaxPoolin  (8, 30, 30, 64)          0
#  g2D)
#
#  conv2d_13 (Conv2D)          (8, 28, 28, 64)           36928
#
#  max_pooling2d_13 (MaxPoolin  (8, 14, 14, 64)          0
#  g2D)
#
#  flatten_2 (Flatten)         (8, 12544)                0
#
#  dense_4 (Dense)             (8, 64)                   802880
#
#  dense_5 (Dense)             (8, 2)                    130
#
# =================================================================
# Total params: 896,258
# Trainable params: 896,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling model
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %%
# fitting the model
history = model.fit(
    train_ds,
    epochs=25,
    batch_size = 8,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 2s 117ms/step - loss: 0.8253 - accuracy: 0.4921 - val_loss: 0.6879 - val_accuracy: 0.4286
# Epoch 2/25
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6771 - accuracy: 0.5714 - val_loss: 0.6557 - val_accuracy: 0.5000
# Epoch 3/25
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6465 - accuracy: 0.5312 - val_loss: 0.5695 - val_accuracy: 0.5714
# Epoch 4/25
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6957 - accuracy: 0.6032 - val_loss: 0.6290 - val_accuracy: 0.8750
# Epoch 5/25
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6173 - accuracy: 0.6508 - val_loss: 0.5749 - val_accuracy: 0.6250
# Epoch 6/25
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5999 - accuracy: 0.6349 - val_loss: 0.3660 - val_accuracy: 1.0000
# Epoch 7/25
# 8/8 [==============================] - 1s 94ms/step - loss: 0.5208 - accuracy: 0.7969 - val_loss: 0.3071 - val_accuracy: 0.7500
# Epoch 8/25
# 8/8 [==============================] - 1s 93ms/step - loss: 0.5121 - accuracy: 0.8095 - val_loss: 0.4141 - val_accuracy: 0.8750
# Epoch 9/25
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4047 - accuracy: 0.8730 - val_loss: 0.2414 - val_accuracy: 0.8750
# Epoch 10/25
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4648 - accuracy: 0.8095 - val_loss: 0.1737 - val_accuracy: 1.0000
# Epoch 11/25
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3646 - accuracy: 0.8889 - val_loss: 0.2013 - val_accuracy: 1.0000
# Epoch 12/25
# 8/8 [==============================] - 1s 94ms/step - loss: 0.3141 - accuracy: 0.9375 - val_loss: 0.4014 - val_accuracy: 0.7500
# Epoch 13/25
# 8/8 [==============================] - 1s 100ms/step - loss: 0.3333 - accuracy: 0.8254 - val_loss: 0.6416 - val_accuracy: 0.7500
# Epoch 14/25
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3228 - accuracy: 0.8730 - val_loss: 0.4861 - val_accuracy: 0.8750
# Epoch 15/25
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4335 - accuracy: 0.8571 - val_loss: 0.3259 - val_accuracy: 0.8571
# Epoch 16/25
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2889 - accuracy: 0.9206 - val_loss: 0.2967 - val_accuracy: 0.8750
# Epoch 17/25
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2540 - accuracy: 0.8889 - val_loss: 0.0929 - val_accuracy: 1.0000
# Epoch 18/25
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2518 - accuracy: 0.8730 - val_loss: 0.0529 - val_accuracy: 1.0000
# Epoch 19/25
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4433 - accuracy: 0.7937 - val_loss: 0.1232 - val_accuracy: 1.0000
# Epoch 20/25
# 8/8 [==============================] - 1s 94ms/step - loss: 0.3181 - accuracy: 0.8438 - val_loss: 0.2545 - val_accuracy: 0.8750
# Epoch 21/25
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2912 - accuracy: 0.8571 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 22/25
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2438 - accuracy: 0.9062 - val_loss: 0.4460 - val_accuracy: 0.7500
# Epoch 23/25
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2267 - accuracy: 0.9048 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 24/25
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1895 - accuracy: 0.9524 - val_loss: 0.3079 - val_accuracy: 0.8750
# Epoch 25/25
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2512 - accuracy: 0.9048 - val_loss: 0.0265 - val_accuracy: 1.0000

# %%
# Testing the created model aganist the test dataset
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 1s 13ms/step - loss: 0.2283 - accuracy: 0.9375
# [0.2282540649175644, 0.9375]

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# plotting the training accuracy and validation accuracy
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(range(25), accuracy, label='Training Accuracy')
plt.plot(range(25), val_accuracy, label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
